# %%
pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.9/813.9 kB 20.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 8.1 MB/s eta 0:00:00
# ...

# %%
import easyocr

reader = easyocr.Reader(['en'])
result = reader.readtext('pic.png')

# Extract text from the OCR result
extracted_text = [text for _, text, _ in result]

# Print the extracted text
print(extracted_text)
# Out:
# ['TEXAS', 'KFL+7030']

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.4/614.4 kB 10.1 MB/s eta 0:00:00
# ...

# %%
# !rm -r /content/yolov7-license-plate-detection-2

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 209MB/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="vW1x1n9PzaBtu8QLxr13")
project = rf.workspace("booker-smith-esjpi").project("lp-cb6nd")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.149, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to lp-2 in yolov8:: 100%|██████████| 1226/1226 [00:00<00:00, 2256.86it/s]

# %%
model.train(data='/content/lp-2/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
